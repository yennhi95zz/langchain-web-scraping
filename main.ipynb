# %% [markdown]
# # Web Scraping with 5 Different Methods: All You Need to Know
# ### Don't miss the last method using LLM for Web Scraping
#
# ![Author](https://img.shields.io/badge/Author-Nhi%20Yen-brightgreen)
# [![Medium](https://img.shields.io/badge/Medium-Follow%20Me-blue)](https://medium.com/@yennhi95zz/subscribe)
# [![GitHub](https://img.shields.io/badge/GitHub-Follow%20Me-lightgrey)](https://github.com/yennhi95zz)
# [![Kaggle](https://img.shields.io/badge/Kaggle-Follow%20Me-orange)](https://www.kaggle.com/nhiyen/code)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Connect%20with%20Me-informational)](https://www.linkedin.com/in/yennhi95zz/)
#
#
# This notebook is associated with the articles/ project below:
# - Find the complete code on this [GitHub repository](https://github.com/yennhi95zz/langchain-web-scraping).
# - Explore a detailed explanation in my [Medium article](https://medium.com/@yennhi95zz/everything-about-how-to-web-scrape-using-5-different-methods-403a59fceea0).
# - Experiment Tracking in [Commet LLM Project](https://www.comet.com/yennhi95zz/langchain-web-scraping/prompts)
#
# Get UNLIMITED access to every story on Medium with just $1/week ▶ [HERE](https://medium.com/@yennhi95zz/membership)

# %% [markdown]
# # Method 1: BeautifulSoup and Requests

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.imdb.com/list/ls566941243/"

# Step 1: Send a GET request to the specified URL
response = requests.get(url)

# Step 2: Parse the HTML content of the response using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Step 3: Save the HTML content to a text file for reference
with open("imdb_bs4_html.txt", "w", encoding="utf-8") as file:
    file.write(str(soup))
print("Page content has been saved to imdb_bs4_html.txt")

# Step 4: Extract movie data from the parsed HTML and store it in a list
movies_data = []
for movie in soup.find_all('div', class_='lister-item-content'):
    title = movie.find('a').text
    genre = movie.find('span', class_='genre').text.strip()
    stars = movie.find('div', class_='ipl-rating-star').find('span', class_='ipl-rating-star__rating').text
    runtime = movie.find('span', class_='runtime').text
    rating = movie.find('span', class_='ipl-rating-star__rating').text
    movies_data.append([title, genre, stars, runtime, rating])

# Step 5: Create a Pandas DataFrame from the extracted movie data
df = pd.DataFrame(movies_data, columns=['Title', 'Genre', 'Stars', 'Runtime', 'Rating'])

# Display the resulting DataFrame
df
# Out:
# Page content has been saved to imdb_bs4_html.txt
#                             Title                     Genre Stars  Runtime  \
# 0                    Bullet Train  Action, Comedy, Thriller   7.3  127 min
# 1                    Emancipation          Action, Thriller   6.2  132 min
# 2                   Violent Night  Action, Comedy, Thriller   6.7  112 min
# 3               Top Gun: Maverick             Action, Drama   8.3  130 min
# 4                      The Batman      Action, Crime, Drama   7.8  176 min
# ..                            ...                       ...   ...      ...
# 95                     Wolf Hound    Action, Adventure, War   3.7  130 min
# 96                        Pursuit      Action, Crime, Drama   2.8   95 min
# 97                   The Commando          Action, Thriller   3.3   93 min
# 98                  Wolves of War     Action, Thriller, War   3.9   87 min
# 99  Diabolik - Ginko all'attacco!    Action, Crime, Mystery   5.4  116 min
#
#    Rating
# 0     7.3
# 1     6.2
# 2     6.7
# 3     8.3
# 4     7.8
# ..    ...
# 95    3.7
# 96    2.8
# 97    3.3
# 98    3.9
# 99    5.4
#
# [100 rows x 5 columns]

# %% [markdown]
# # Method 2: Scrapy

# %%
url = "https://www.imdb.com/list/ls566941243/"

# %%
# Import necessary libraries
import scrapy
from scrapy.crawler import CrawlerProcess

# Define the Spider class for IMDb data extraction
class IMDbSpider(scrapy.Spider):
    # Name of the spider
    name = "imdb_spider"
    # Starting URL(s) for the spider to crawl
    # start_urls = ["https://www.imdb.com/list/ls566941243/"]
    start_urls = [url]

    # Parse method to extract data from the webpage
    def parse(self, response):
        # Iterate over each movie item on the webpage
        for movie in response.css('div.lister-item-content'):
            yield {
                'title': movie.css('h3.lister-item-header a::text').get(),
                'genre': movie.css('p.text-muted span.genre::text').get(),
                'runtime': movie.css('p.text-muted span.runtime::text').get(),
                'rating': movie.css('div.ipl-rating-star span.ipl-rating-star__rating::text').get(),
            }
# Initialize a CrawlerProcess instance with settings
process = CrawlerProcess(settings={
    'FEED_FORMAT': 'json',
    'FEED_URI': 'output_scrapy.json',  # This will overwrite the file every time you run the spider
})


# Add the IMDbSpider to the crawling process
process.crawl(IMDbSpider)
# Start the crawling process
process.start()
# Out:
# 2024-02-07 21:19:07 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapybot)
# 2024-02-07 21:19:07 [scrapy.utils.log] INFO: Versions: lxml 5.1.0.0, libxml2 2.12.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.10.13 (main, Nov  1 2023, 16:44:37) [Clang 14.0.0 (clang-1400.0.29.202)], pyOpenSSL 24.0.0 (OpenSSL 3.2.1 30 Jan 2024), cryptography 42.0.2, Platform macOS-12.7.1-x86_64-i386-64bit
# 2024-02-07 21:19:07 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-02-07 21:19:07 [py.warnings] WARNING: /Users/admin/Desktop/medium-how-to-web-scraping/.venv/lib/python3.10/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-02-07 21:19:07 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2024-02-07 21:19:07 [scrapy.extensions.telnet] INFO: Telnet Password: 59c2cc80a63c9e02
# 2024-02-07 21:19:07 [py.warnings] WARNING: /Users/admin/Desktop/medium-how-to-web-scraping/.venv/lib/python3.10/site-packages/scrapy/extensions/feedexport.py:406: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
#   exporter = cls(crawler)
#
# 2024-02-07 21:19:07 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-02-07 21:19:07 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2024-02-07 21:19:07 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-02-07 21:19:07 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-02-07 21:19:07 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-02-07 21:19:07 [scrapy.core.engine] INFO: Spider opened
# 2024-02-07 21:19:07 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-02-07 21:19:07 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6030
# 2024-02-07 21:19:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/list/ls566941243/> (referer: None)
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Bullet Train', 'genre': '\nAction, Comedy, Thriller            ', 'runtime': '127 min', 'rating': '7.3'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Emancipation', 'genre': '\nAction, Thriller            ', 'runtime': '132 min', 'rating': '6.2'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Violent Night', 'genre': '\nAction, Comedy, Thriller            ', 'runtime': '112 min', 'rating': '6.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Top Gun: Maverick', 'genre': '\nAction, Drama            ', 'runtime': '130 min', 'rating': '8.3'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The Batman', 'genre': '\nAction, Crime, Drama            ', 'runtime': '176 min', 'rating': '7.8'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'All Quiet on the Western Front', 'genre': '\nAction, Drama, War            ', 'runtime': '148 min', 'rating': '7.8'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Devotion', 'genre': '\nAction, Biography, Drama            ', 'runtime': '139 min', 'rating': '6.6'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The Gray Man', 'genre': '\nAction, Thriller            ', 'runtime': '122 min', 'rating': '6.5'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Enola Holmes 2', 'genre': '\nAction, Adventure, Crime            ', 'runtime': '129 min', 'rating': '6.8'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Uncharted', 'genre': '\nAction, Adventure            ', 'runtime': '116 min', 'rating': '6.3'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Memory', 'genre': '\nAction, Crime, Thriller            ', 'runtime': '114 min', 'rating': '5.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The Big 4', 'genre': '\nAction, Comedy, Crime            ', 'runtime': '141 min', 'rating': '6.1'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'My Name Is Vendetta', 'genre': '\nAction, Crime, Drama            ', 'runtime': '90 min', 'rating': '5.5'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Poker Face', 'genre': '\nAction, Crime, Thriller            ', 'runtime': '94 min', 'rating': '5.2'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Detective Knight: Redemption', 'genre': '\nAction, Adventure, Mystery            ', 'runtime': '97 min', 'rating': '4'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The Unbearable Weight of Massive Talent', 'genre': '\nAction, Comedy, Crime            ', 'runtime': '107 min', 'rating': '7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Ambulance', 'genre': '\nAction, Crime, Drama            ', 'runtime': '136 min', 'rating': '6.1'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Savage Salvation', 'genre': '\nAction, Thriller            ', 'runtime': '101 min', 'rating': '4.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Lou', 'genre': '\nAction, Adventure, Crime            ', 'runtime': '107 min', 'rating': '6.1'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Samaritan', 'genre': '\nAction, Drama, Fantasy            ', 'runtime': '102 min', 'rating': '5.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'R.I.P.D. 2: Rise of the Damned', 'genre': '\nAction, Adventure, Comedy            ', 'runtime': '102 min', 'rating': '4.6'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Spiderhead', 'genre': '\nAction, Crime, Drama            ', 'runtime': '106 min', 'rating': '5.5'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Last Seen Alive', 'genre': '\nAction, Adventure, Crime            ', 'runtime': '95 min', 'rating': '5.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Blacklight', 'genre': '\nAction, Drama, Thriller            ', 'runtime': '104 min', 'rating': '4.8'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The Contractor', 'genre': '\nAction, Drama, Thriller            ', 'runtime': '103 min', 'rating': '5.8'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Athena', 'genre': '\nAction, Drama, Thriller            ', 'runtime': '99 min', 'rating': '6.8'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Sniper: Rogue Mission', 'genre': '\nAction, Thriller            ', 'runtime': '96 min', 'rating': '4.6'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'White Elephant', 'genre': '\nAction, Thriller            ', 'runtime': '92 min', 'rating': '4.4'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Mad Heidi', 'genre': '\nAction, Adventure, Comedy            ', 'runtime': '92 min', 'rating': '5.5'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Paradise City', 'genre': '\nAction, Thriller            ', 'runtime': '92 min', 'rating': '3.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Detective Knight: Rogue', 'genre': '\nAction, Adventure, Crime            ', 'runtime': '105 min', 'rating': '3.8'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Renegades', 'genre': '\nAction, Crime, Thriller            ', 'runtime': '91 min', 'rating': '3.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The Man from Toronto', 'genre': '\nAction, Adventure, Comedy            ', 'runtime': '110 min', 'rating': '5.8'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The 355', 'genre': '\nAction, Thriller            ', 'runtime': '122 min', 'rating': '5.6'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Interceptor', 'genre': '\nAction, Adventure, Drama            ', 'runtime': '99 min', 'rating': '4.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Lesson Plan', 'genre': '\nAction, Crime, Drama            ', 'runtime': '101 min', 'rating': '5'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Wrong Place', 'genre': '\nAction, Crime, Thriller            ', 'runtime': '96 min', 'rating': '3.5'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The Enforcer', 'genre': '\nAction, Crime, Drama            ', 'runtime': '90 min', 'rating': '5.3'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'One Way', 'genre': '\nAction, Thriller            ', 'runtime': '95 min', 'rating': '4.1'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Shotgun Wedding', 'genre': '\nAction, Comedy, Romance            ', 'runtime': '101 min', 'rating': '5.4'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Vendetta', 'genre': '\nAction, Thriller            ', 'runtime': '96 min', 'rating': '3.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The Takeover', 'genre': '\nAction, Crime, Thriller            ', 'runtime': '87 min', 'rating': '5.3'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'As Good as Dead', 'genre': '\nAction, Crime            ', 'runtime': '89 min', 'rating': '5.5'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Blackout', 'genre': '\nAction, Crime, Thriller            ', 'runtime': '81 min', 'rating': '3.8'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Gold', 'genre': '\nAction, Adventure, Thriller            ', 'runtime': '97 min', 'rating': '5.4'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'No Way Out', 'genre': '\nAction, Crime, Thriller            ', 'runtime': '89 min', 'rating': '3.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Black Crab', 'genre': '\nAction, Adventure, Drama            ', 'runtime': '114 min', 'rating': '5.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The Lair', 'genre': '\nAction, Horror, Sci-Fi            ', 'runtime': '97 min', 'rating': '4.6'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The System', 'genre': '\nAction, Crime            ', 'runtime': '97 min', 'rating': '4.2'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Run & Gun', 'genre': '\nAction, Thriller            ', 'runtime': '96 min', 'rating': '5.3'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Overdose', 'genre': '\nAction, Crime, Thriller            ', 'runtime': '119 min', 'rating': '5.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The Ambush', 'genre': '\nAction, Drama, War            ', 'runtime': '102 min', 'rating': '6.2'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Lost Bullet 2: Back for More', 'genre': '\nAction, Crime, Thriller            ', 'runtime': '98 min', 'rating': '6.3'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': "Accident Man: Hitman's Holiday", 'genre': '\nAction, Comedy, Crime            ', 'runtime': '96 min', 'rating': '5.9'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Black Site', 'genre': '\nAction, Thriller            ', 'runtime': '93 min', 'rating': '4.4'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Fistful of Vengeance', 'genre': '\nAction, Crime, Drama            ', 'runtime': '96 min', 'rating': '4.4'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Sound of Freedom', 'genre': '\nBiography, Crime, Drama            ', 'runtime': '131 min', 'rating': '7.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Section 8', 'genre': '\nAction, Thriller            ', 'runtime': '98 min', 'rating': '4.3'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The Price We Pay', 'genre': '\nAction, Horror, Thriller            ', 'runtime': '86 min', 'rating': '4.9'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'End of the Road', 'genre': '\nAction, Crime, Drama            ', 'runtime': '89 min', 'rating': '4.8'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'High Heat', 'genre': '\nAction, Comedy, Crime            ', 'runtime': '84 min', 'rating': '4.8'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Black Warrant', 'genre': '\nAction, Thriller            ', 'runtime': '94 min', 'rating': '4.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Wire Room', 'genre': '\nAction, Thriller            ', 'runtime': '96 min', 'rating': '3.6'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Corrective Measures', 'genre': '\nAction, Sci-Fi            ', 'runtime': '106 min', 'rating': '4.5'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Code Name Banshee', 'genre': '\nAction, Thriller            ', 'runtime': '88 min', 'rating': '3.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Avarice', 'genre': '\nAction, Thriller            ', 'runtime': '88 min', 'rating': '5.3'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Blackbird', 'genre': '\nAction, Romance, Thriller            ', 'runtime': '88 min', 'rating': '2.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Restless', 'genre': '\nAction, Crime, Thriller            ', 'runtime': '95 min', 'rating': '5.8'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The Moderator', 'genre': '\nAction, Drama, Thriller            ', 'runtime': '82 min', 'rating': '4.9'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Operation Seawolf', 'genre': '\nAction, Adventure, History            ', 'runtime': '87 min', 'rating': '3.3'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Agent Game', 'genre': '\nAction, Thriller            ', 'runtime': '90 min', 'rating': '4'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'A Day to Die', 'genre': '\nAction, Crime, Drama            ', 'runtime': '105 min', 'rating': '3.5'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Double Threat', 'genre': '\nAction, Comedy, Thriller            ', 'runtime': '92 min', 'rating': '4.7'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Panama', 'genre': '\nAction, Thriller            ', 'runtime': '95 min', 'rating': '3.5'}
# 2024-02-07 21:19:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': "Fortress: Sniper's Eye", 'genre': '\nAction, Thriller            ', 'runtime': '87 min', 'rating': '3'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Maneater', 'genre': '\nAction, Horror, Thriller            ', 'runtime': '87 min', 'rating': '3.1'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Battle for Pandora', 'genre': '\nAction, Horror, Sci-Fi            ', 'runtime': '85 min', 'rating': '2.6'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The Takedown', 'genre': '\nAction, Comedy, Crime            ', 'runtime': '119 min', 'rating': '5.8'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Hounded', 'genre': '\nAction, Horror, Thriller            ', 'runtime': '94 min', 'rating': '5'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The Retirement Plan', 'genre': '\nAction, Comedy, Crime            ', 'runtime': '103 min', 'rating': '5.1'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Robbing Mussolini', 'genre': '\nAction, Comedy, Crime            ', 'runtime': '90 min', 'rating': '5.4'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Hellblazers', 'genre': '\nAction, Horror            ', 'runtime': '84 min', 'rating': '4.5'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Gasoline Alley', 'genre': '\nAction, Thriller            ', 'runtime': '97 min', 'rating': '3.9'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'WarHunt', 'genre': '\nAction, Horror, Thriller            ', 'runtime': '93 min', 'rating': '4.4'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Repeater', 'genre': '\nAction            ', 'runtime': '106 min', 'rating': '3.9'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': '2025: Blood, White & Blue', 'genre': '\nAction, Comedy, Horror            ', 'runtime': '135 min', 'rating': '2.2'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Tell It Like a Woman', 'genre': '\nAction, Comedy, Drama            ', 'runtime': '112 min', 'rating': '3.7'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Blowback', 'genre': '\nAction, Crime, Thriller            ', 'runtime': '93 min', 'rating': '4.2'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Battle for Saipan', 'genre': '\nAction, Thriller, War            ', 'runtime': '94 min', 'rating': '3.9'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Eraser: Reborn', 'genre': '\nAction, Crime, Thriller            ', 'runtime': '102 min', 'rating': '4.6'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Death Hunt', 'genre': '\nAction, Thriller            ', 'runtime': '92 min', 'rating': '3.7'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Croc!', 'genre': '\nAction, Horror            ', 'runtime': '85 min', 'rating': '2.6'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The Hyperions', 'genre': '\nAction, Comedy            ', 'runtime': '90 min', 'rating': '5.2'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Boon', 'genre': '\nAction, Crime, Drama            ', 'runtime': '95 min', 'rating': '4.9'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'There Are No Saints', 'genre': '\nAction, Thriller            ', 'runtime': '105 min', 'rating': '4.8'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Wolf Hound', 'genre': '\nAction, Adventure, War            ', 'runtime': '130 min', 'rating': '3.7'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Pursuit', 'genre': '\nAction, Crime, Drama            ', 'runtime': '95 min', 'rating': '2.8'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'The Commando', 'genre': '\nAction, Thriller            ', 'runtime': '93 min', 'rating': '3.3'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Wolves of War', 'genre': '\nAction, Thriller, War            ', 'runtime': '87 min', 'rating': '3.9'}
# 2024-02-07 21:19:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/list/ls566941243/>
# {'title': 'Diabolik: Ginko Attacks', 'genre': '\nAction, Crime, Mystery            ', 'runtime': '116 min', 'rating': '5.4'}
# 2024-02-07 21:19:15 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-02-07 21:19:15 [scrapy.extensions.feedexport] INFO: Stored json feed (100 items) in: output_scrapy.json
# 2024-02-07 21:19:15 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 230,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 2211748,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 7.409482,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 2, 7, 13, 19, 15, 372052, tzinfo=datetime.timezone.utc),
#  'item_scraped_count': 100,
#  'log_count/DEBUG': 102,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 2,
#  'memusage/max': 189763584,
#  'memusage/startup': 189763584,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2024, 2, 7, 13, 19, 7, 962570, tzinfo=datetime.timezone.utc)}
# 2024-02-07 21:19:15 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import pandas as pd

# Read the output.json file into a DataFrame (jsonlines format)
df = pd.read_json('output_scrapy.json')

# Display the DataFrame
df.head()
# Out:
#                title                                   genre  runtime  rating
# 0       Bullet Train  \nAction, Comedy, Thriller              127 min     7.3
# 1       Emancipation          \nAction, Thriller              132 min     6.2
# 2      Violent Night  \nAction, Comedy, Thriller              112 min     6.7
# 3  Top Gun: Maverick             \nAction, Drama              130 min     8.3
# 4         The Batman      \nAction, Crime, Drama              176 min     7.8

# %% [markdown]
# # Method 3: Selenium

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# URL of the IMDb list
url = "https://www.imdb.com/list/ls566941243/"

# Set up Chrome options to run the browser in incognito mode
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--incognito")

# Initialize the Chrome driver with the specified options
driver = webdriver.Chrome(options=chrome_options)

# Navigate to the IMDb list URL
driver.get(url)

# Wait for the page to load (adjust the wait time according to your webpage)
driver.implicitly_wait(10)

# Get the HTML content of the page after it has fully loaded
html_content = driver.page_source

# Parse the HTML content with BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Save the HTML content to a text file for reference
with open("imdb_selenium_html.txt", "w", encoding="utf-8") as file:
    file.write(str(soup))
print("Page content has been saved to imdb_selenium_html.txt")

# Extract movie data from the parsed HTML
movies_data = []
for movie in soup.find_all('div', class_='lister-item-content'):
    title = movie.find('a').text
    genre = movie.find('span', class_='genre').text.strip()
    stars = movie.select_one('div.ipl-rating-star span.ipl-rating-star__rating').text
    runtime = movie.find('span', class_='runtime').text
    rating = movie.select_one('div.ipl-rating-star span.ipl-rating-star__rating').text
    movies_data.append([title, genre, stars, runtime, rating])

# Create a Pandas DataFrame from the collected movie data
df = pd.DataFrame(movies_data, columns=['Title', 'Genre', 'Stars', 'Runtime', 'Rating'])

# Display the resulting DataFrame
print(df)

# Close the Chrome driver
driver.quit()
# Out:
# 2024-02-07 21:19:15 [selenium.webdriver.common.selenium_manager] DEBUG: Selenium Manager binary found at: /Users/admin/Desktop/medium-how-to-web-scraping/.venv/lib/python3.10/site-packages/selenium/webdriver/common/macos/selenium-manager
# 2024-02-07 21:19:15 [selenium.webdriver.common.selenium_manager] DEBUG: Executing process: /Users/admin/Desktop/medium-how-to-web-scraping/.venv/lib/python3.10/site-packages/selenium/webdriver/common/macos/selenium-manager --browser chrome --language-binding python --output json
# 2024-02-07 21:19:16 [selenium.webdriver.common.selenium_manager] DEBUG: Driver path: /Users/admin/.cache/selenium/chromedriver/mac-x64/121.0.6167.85/chromedriver
# 2024-02-07 21:19:16 [selenium.webdriver.common.selenium_manager] DEBUG: Browser path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
# 2024-02-07 21:19:16 [selenium.webdriver.common.selenium_manager] DEBUG: Using driver at: /Users/admin/.cache/selenium/chromedriver/mac-x64/121.0.6167.85/chromedriver
# 2024-02-07 21:19:16 [selenium.webdriver.common.service] DEBUG: Started executable: `/Users/admin/.cache/selenium/chromedriver/mac-x64/121.0.6167.85/chromedriver` in a child process with pid: 11766 using 0 to output -3
# 2024-02-07 21:19:16 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://localhost:56988/session {'capabilities': {'firstMatch': [{}], 'alwaysMatch': {'browserName': 'chrome', 'pageLoadStrategy': <PageLoadStrategy.normal: 'normal'>, 'browserVersion': None, 'goog:chromeOptions': {'extensions': [], 'binary': '/Applications/Google Chrome.app/Contents/MacOS/Google Chrome', 'args': ['--incognito']}}}}
# 2024-02-07 21:19:16 [urllib3.connectionpool] DEBUG: Starting new HTTP connection (1): localhost:56988
# 2024-02-07 21:19:20 [urllib3.connectionpool] DEBUG: http://localhost:56988 "POST /session HTTP/1.1" 200 0
# 2024-02-07 21:19:20 [selenium.webdriver.remote.remote_connection] DEBUG: Remote response: status=200 | data={"value":{"capabilities":{"acceptInsecureCerts":false,"browserName":"chrome","browserVersion":"121.0.6167.139","chrome":{"chromedriverVersion":"121.0.6167.85 (3f98d690ad7e59242ef110144c757b2ac4eef1a2-refs/branch-heads/6167@{#1539})","userDataDir":"/var/folders/4v/t4hb9zbj0lj6cfm17k_m7m5c0000gn/T/.org.chromium.Chromium.Odjlni"},"fedcm:accounts":true,"goog:chromeOptions":{"debuggerAddress":"localhost:56999"},"networkConnectionEnabled":false,"pageLoadStrategy":"normal","platformName":"mac","proxy":{},"setWindowRect":true,"strictFileInteractability":false,"timeouts":{"implicit":0,"pageLoad":300000,"script":30000},"unhandledPromptBehavior":"dismiss and notify","webauthn:extension:credBlob":true,"webauthn:extension:largeBlob":true,"webauthn:extension:minPinLength":true,"webauthn:extension:prf":true,"webauthn:virtualAuthenticators":true},"sessionId":"c7e5ad7b3dcd8567c224e1b550d4de31"}} | headers=HTTPHeaderDict({'Content-Length': '891', 'Content-Type': 'application/json; charset=utf-8', 'cache-control': 'no-cache'})
# 2024-02-07 21:19:20 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2024-02-07 21:19:20 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://localhost:56988/session/c7e5ad7b3dcd8567c224e1b550d4de31/url {'url': 'https://www.imdb.com/list/ls566941243/'}
# 2024-02-07 21:19:29 [urllib3.connectionpool] DEBUG: http://localhost:56988 "POST /session/c7e5ad7b3dcd8567c224e1b550d4de31/url HTTP/1.1" 200 0
# 2024-02-07 21:19:29 [selenium.webdriver.remote.remote_connection] DEBUG: Remote response: status=200 | data={"value":null} | headers=HTTPHeaderDict({'Content-Length': '14', 'Content-Type': 'application/json; charset=utf-8', 'cache-control': 'no-cache'})
# 2024-02-07 21:19:29 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2024-02-07 21:19:29 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://localhost:56988/session/c7e5ad7b3dcd8567c224e1b550d4de31/timeouts {'implicit': 10000}
# 2024-02-07 21:19:29 [urllib3.connectionpool] DEBUG: http://localhost:56988 "POST /session/c7e5ad7b3dcd8567c224e1b550d4de31/timeouts HTTP/1.1" 200 0
# 2024-02-07 21:19:29 [selenium.webdriver.remote.remote_connection] DEBUG: Remote response: status=200 | data={"value":null} | headers=HTTPHeaderDict({'Content-Length': '14', 'Content-Type': 'application/json; charset=utf-8', 'cache-control': 'no-cache'})
# 2024-02-07 21:19:29 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2024-02-07 21:19:29 [selenium.webdriver.remote.remote_connection] DEBUG: GET http://localhost:56988/session/c7e5ad7b3dcd8567c224e1b550d4de31/source {}
# 2024-02-07 21:19:29 [urllib3.connectionpool] DEBUG: http://localhost:56988 "GET /session/c7e5ad7b3dcd8567c224e1b550d4de31/source HTTP/1.1" 200 0
# 2024-02-07 21:19:30 [selenium.webdriver.remote.remote_connection] DEBUG: Remote response: status=200 | data={"value":"\u003Chtml xmlns:og=\"http://ogp.me/ns#\" xmlns:fb=\"http://www.facebook.com/2008/fbml\" class=\" scriptsOn\">\u003Chead>\u003Cscript async=\"\" src=\"https://images-na.ssl-images-amazon.com/images/I/31bJewCvY-L.js\" crossorigin=\"anonymous\">\u003C/script>\n        \n\u003Cscript async=\"\" src=\"https://sb.scorecardresearch.com/beacon.js\">\u003C/script>\u003Cscript type=\"text/javascript\">var ue_t0=ue_t0||+new Date();\u003C/script>\n\u003Cscript type=\"text/javascript\">\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||\"undefined\",logLevel:\"WARN\"})}}}})(ue_csm);\n\n\n    var ue_err_chan = 'jserr';\n(function(d,e){function h(f,b){if(!(a.ec>a.mxe)&&f){a.ter.push(f);b=b||{};var c=f.logLevel||b.logLevel;c&&c!==k&&c!==m&&c!==n&&c!==p||a.ec++;c&&c!=k||a.ecf++;b.pageURL=\"\"+(e.location?e.location.href:\"\");b.logLevel=c;b.attribution=f.attribution||b.attribution;a.erl.push({ex:f,info:b})}}function l(a,b,c,e,g){d.ueLogError({m:a,f:b,l:c,c:\"\"+e,err:g,fromOnError:1,args:arguments},g?{attribution:g.attribution,logLevel:g.logLevel}:void 0);return!1}var k=\"FATAL\",m=\"ERROR\",n=\"WARN\",p=\"DOWNGRADED\",a={ec:0,ecf:0,\npec:0,ts:0,erl:[],ter:[],buffer:[],mxe:50,startTimer:function(){a.ts++;setInterval(function(){d.ue&&a.pec\u003Ca.ec&&d.uex(\"at\");a.pec=a.ec},1E4)}};l.skipTrace=1;h.skipTrace=1;h.isStub=1;d.ueLogError=h;d.ue_err=a;e.onerror=l})(ue_csm,window);\n\n\nvar ue_id = 'Y8V488GKHSE6N6Q4P94G',\n    ue_url,\n    ue_navtiming = 1,\n    ue_mid = 'A1EVAM02EL8SFB',\n    ue_sid = '132-9614846-1522808',\n    ue_sn = 'www.imdb.com',\n    ue_furl = 'fls-na.amazon.com',\n    ue_surl = 'https://unagi-na.amazon.com/1/events/com.amazon.csm.nexusclient.prod',\n    ue_int = 0,\n    ue_fcsn = 1,\n    ue_urt = 3,\n    ue_rpl_ns = 'cel-rpl',\n    ue_ddq = 1,\n    ue_fpf = '//fls-na.amazon.com/1/batch/1/OP/A1EVAM02EL8SFB:132-9614846-1522808:Y8V488GKHSE6N6Q4P94G$uedata=s:',\n    ue_sbuimp = 1,\n    ue_ibft = 0,\n    ue_sswmts = 0,\n    ue_jsmtf = 0,\n    ue_fnt = 0,\n    ue_lpsi = 6000,\n    ue_no_counters = 0,\n    ue_lob = '6',\n    ue_sjslob = 0,\n\n    ue_swi = 1;\nvar ue_viz=function(){(function(b,f,d){function g(){return(!(p in d)||0\u003Cd[p])&&(!(q in d)||0\u003Cd[q])}function h(c){if(b.ue.viz.length\u003Cw&&!r){var a=c.type;c=c.originalEvent;/^focus./.test(a)&&c&&(c.toElement||c.fromElement||c.relatedTarget)||(a=g()?f[s]||(\"blur\"==a||\"focusout\"==a?t:u):t,b.ue.viz.push(a+\":\"+(+new Date-b.ue.t0)),a==u&&(b.ue.isl&&x(\"at\"),r=1))}}for(var r=0,x=b.uex,a,k,l,s,v=[\"\",\"webkit\",\"o\",\"ms\",\"moz\"],e=0,m=1,u=\"visible\",t=\"hidden\",p=\"innerWidth\",q=\"innerHeight\",w=20,n=0;n\u003Cv.length&&!e;n++)if(a=\nv[n],k=(a?a+\"H\":\"h\")+\"idden\",e=\"boolean\"==typeof f[k])l=a+\"visibilitychange\",s=(a?a+\"V\":\"v\")+\"isibilityState\";h({});e&&f.addEventListener(l,h,0);m=g()?1:0;d.addEventListener(\"resize\",function(){var a=g()?1:0;m!==a&&(m=a,h({}))},{passive:!0});b.ue&&e&&(b.ue.pageViz={event:l,propHid:k})})(ue_csm,ue_csm.document,ue_csm.window)};\n\n(function(d,h,N){function H(a){return a&&a.replace&&a.replace(/^\\s+|\\s+$/g,\"\")}function u(a){return\"undefined\"===typeof a}function B(a,b){for(var c in b)b[v](c)&&(a[c]=b[c])}function I(a){try{var b=N.cookie.match(RegExp(\"(^| )\"+a+\"=([^;]+)\"));if(b)return b[2].trim()}catch(c){}}function O(k,b,c){var q=(x||{}).type;if(\"device\"!==c||2!==q&&1!==q)k&&(d.ue_id=a.id=a.r ...
# 2024-02-07 21:19:30 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# Page content has been saved to imdb_selenium_html.txt
# 2024-02-07 21:19:35 [selenium.webdriver.remote.remote_connection] DEBUG: DELETE http://localhost:56988/session/c7e5ad7b3dcd8567c224e1b550d4de31 {}
#                       Title                     Genre Stars  Runtime Rating
# 0              Bullet Train  Action, Comedy, Thriller   7.3  127 min    7.3
# 1              Emancipation          Action, Thriller   6.2  132 min    6.2
# 2             Violent Night  Action, Comedy, Thriller   6.7  112 min    6.7
# 3         Top Gun: Maverick             Action, Drama   8.3  130 min    8.3
# 4                The Batman      Action, Crime, Drama   7.8  176 min    7.8
# ..                      ...                       ...   ...      ...    ...
# 95               Wolf Hound    Action, Adventure, War   3.7  130 min    3.7
# 96                  Pursuit      Action, Crime, Drama   2.8   95 min    2.8
# 97             The Commando          Action, Thriller   3.3   93 min    3.3
# 98            Wolves of War     Action, Thriller, War   3.9   87 min    3.9
# 99  Diabolik: Ginko Attacks    Action, Crime, Mystery   5.4  116 min    5.4
#
# [100 rows x 5 columns]
# 2024-02-07 21:19:35 [urllib3.connectionpool] DEBUG: http://localhost:56988 "DELETE /session/c7e5ad7b3dcd8567c224e1b550d4de31 HTTP/1.1" 200 0
# 2024-02-07 21:19:35 [selenium.webdriver.remote.remote_connection] DEBUG: Remote response: status=200 | data={"value":null} | headers=HTTPHeaderDict({'Content-Length': '14', 'Content-Type': 'application/json; charset=utf-8', 'cache-control': 'no-cache'})
# 2024-02-07 21:19:35 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request

# %% [markdown]
# # Method 4: Requests and lxml

# %%
import requests
from lxml import html
import pandas as pd

# Define the URL
url = "https://www.imdb.com/list/ls566941243/"

# Send an HTTP request to the URL and get the response
response = requests.get(url)

# Parse the HTML content using lxml
tree = html.fromstring(response.content)

# Extract movie data from the parsed HTML
titles = tree.xpath('//h3[@class="lister-item-header"]/a/text()')
genres = [', '.join(genre.strip() for genre in genre_list.xpath(".//text()")) for genre_list in tree.xpath('//p[@class="text-muted text-small"]/span[@class="genre"]')]
ratings = tree.xpath('//div[@class="ipl-rating-star small"]/span[@class="ipl-rating-star__rating"]/text()')
runtimes = tree.xpath('//p[@class="text-muted text-small"]/span[@class="runtime"]/text()')

# Create a dictionary with extracted data
data = {
    'Title': titles,
    'Genre': genres,
    'Rating': ratings,
    'Runtime': runtimes
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Display the resulting DataFrame
df.head()
# Out:
# 2024-02-07 21:19:35 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): www.imdb.com:443
# 2024-02-07 21:19:37 [urllib3.connectionpool] DEBUG: https://www.imdb.com:443 "GET /list/ls566941243/ HTTP/1.1" 200 None
#                Title                     Genre Rating  Runtime
# 0       Bullet Train  Action, Comedy, Thriller    7.3  127 min
# 1       Emancipation          Action, Thriller    6.2  132 min
# 2      Violent Night  Action, Comedy, Thriller    6.7  112 min
# 3  Top Gun: Maverick             Action, Drama    8.3  130 min
# 4         The Batman      Action, Crime, Drama    7.8  176 min

# %% [markdown]
# # Method 5. Langchain
#
# - [LangChain Beautiful Soup](https://python.langchain.com/docs/integrations/document_transformers/beautiful_soup)
# - [LangChain Extraction](https://python.langchain.com/docs/use_cases/extraction)

# %%
import os
import dotenv
import time

# Load environment variables from a .env file
dotenv.load_dotenv()

# Retrieve OpenAI and Comet key from environment variables
MY_OPENAI_KEY = os.getenv("MY_OPENAI_KEY")
MY_COMET_KEY = os.getenv("MY_COMET_KEY")

# %%
import comet_llm

# Initialize a Comet project
comet_llm.init(project="langchain-web-scraping",
               api_key=MY_COMET_KEY,
               )
# Out:
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: []
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['./.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['/content/drive/MyDrive/.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: raise_exceptions_on_error, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_RAISE_EXCEPTIONS_ON_ERROR
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_RAISE_EXCEPTIONS_ON_ERROR
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: raise_exceptions_on_error, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_RAISE_EXCEPTIONS_ON_ERROR
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: raise_exceptions_on_error, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_RAISE_EXCEPTIONS_ON_ERROR
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_RAISE_EXCEPTIONS_ON_ERROR
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: raise_exceptions_on_error, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_RAISE_EXCEPTIONS_ON_ERROR
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: disable, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_DISABLE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_DISABLE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: disable, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_DISABLE
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: raise_exceptions_on_error, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_RAISE_EXCEPTIONS_ON_ERROR
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_RAISE_EXCEPTIONS_ON_ERROR
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: raise_exceptions_on_error, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_RAISE_EXCEPTIONS_ON_ERROR
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: raise_exceptions_on_error, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_RAISE_EXCEPTIONS_ON_ERROR
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_RAISE_EXCEPTIONS_ON_ERROR
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: raise_exceptions_on_error, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_RAISE_EXCEPTIONS_ON_ERROR
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: console, namespace: ['comet', 'logging']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_LOGGING_CONSOLE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_LOGGING_CONSOLE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: console, namespace: ['comet', 'logging']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_LOGGING_CONSOLE
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: []
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['./.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['/content/drive/MyDrive/.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: disable_auto_logging, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_DISABLE_AUTO_LOGGING
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: disable_auto_logging, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: disable, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_DISABLE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_DISABLE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: disable, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_DISABLE
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: []
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['./.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['/content/drive/MyDrive/.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: []
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['./.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['/content/drive/MyDrive/.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: url_override, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_URL_OVERRIDE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_URL_OVERRIDE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: url_override, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_URL_OVERRIDE
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: http, namespace: ['comet', 'timeout']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_TIMEOUT_HTTP
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_TIMEOUT_HTTP
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: http, namespace: ['comet', 'timeout']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_TIMEOUT_HTTP
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: check_tls_certificate, namespace: ['comet', 'internal']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: check_tls_certificate, namespace: ['comet', 'internal']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: []
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['./.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['/content/drive/MyDrive/.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: name, namespace: ['comet', 'allow_header']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_NAME
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_ALLOW_HEADER_NAME
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: name, namespace: ['comet', 'allow_header']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_NAME
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: value, namespace: ['comet', 'allow_header']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_ALLOW_HEADER_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: value, namespace: ['comet', 'allow_header']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: []
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['./.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['/content/drive/MyDrive/.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: retry_total, namespace: ['comet', 'http_session']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_HTTP_SESSION_RETRY_TOTAL
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_HTTP_SESSION_RETRY_TOTAL
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: retry_total, namespace: ['comet', 'http_session']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_HTTP_SESSION_RETRY_TOTAL
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: retry_backoff_factor, namespace: ['comet', 'http_session']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_HTTP_SESSION_RETRY_BACKOFF_FACTOR
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_HTTP_SESSION_RETRY_BACKOFF_FACTOR
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: retry_backoff_factor, namespace: ['comet', 'http_session']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_HTTP_SESSION_RETRY_BACKOFF_FACTOR
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: []
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['./.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['/content/drive/MyDrive/.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: name, namespace: ['comet', 'allow_header']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_NAME
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_ALLOW_HEADER_NAME
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: name, namespace: ['comet', 'allow_header']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_NAME
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: value, namespace: ['comet', 'allow_header']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_ALLOW_HEADER_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: value, namespace: ['comet', 'allow_header']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: []
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['./.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['/content/drive/MyDrive/.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: hide_api_key, namespace: ['comet', 'logging']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_LOGGING_HIDE_API_KEY
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_LOGGING_HIDE_API_KEY
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: hide_api_key, namespace: ['comet', 'logging']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_LOGGING_HIDE_API_KEY
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: []
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['./.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['/content/drive/MyDrive/.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: url_override, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_URL_OVERRIDE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_URL_OVERRIDE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: url_override, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_URL_OVERRIDE
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: api, namespace: ['comet', 'timeout']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_TIMEOUT_API
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_TIMEOUT_API
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: api, namespace: ['comet', 'timeout']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_TIMEOUT_API
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: check_tls_certificate, namespace: ['comet', 'internal']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: check_tls_certificate, namespace: ['comet', 'internal']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: []
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['./.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['/content/drive/MyDrive/.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: name, namespace: ['comet', 'allow_header']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_NAME
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_ALLOW_HEADER_NAME
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: name, namespace: ['comet', 'allow_header']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_NAME
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: value, namespace: ['comet', 'allow_header']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_ALLOW_HEADER_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: value, namespace: ['comet', 'allow_header']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: []
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['./.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['/content/drive/MyDrive/.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: retry_total, namespace: ['comet', 'http_session']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_HTTP_SESSION_RETRY_TOTAL
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_HTTP_SESSION_RETRY_TOTAL
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: retry_total, namespace: ['comet', 'http_session']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_HTTP_SESSION_RETRY_TOTAL
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: retry_backoff_factor, namespace: ['comet', 'http_session']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_HTTP_SESSION_RETRY_BACKOFF_FACTOR
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_HTTP_SESSION_RETRY_BACKOFF_FACTOR
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: retry_backoff_factor, namespace: ['comet', 'http_session']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_HTTP_SESSION_RETRY_BACKOFF_FACTOR
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: []
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['./.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: No INI file found: ['/content/drive/MyDrive/.comet.config']
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: name, namespace: ['comet', 'allow_header']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_NAME
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_ALLOW_HEADER_NAME
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: name, namespace: ['comet', 'allow_header']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_NAME
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: value, namespace: ['comet', 'allow_header']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_ALLOW_HEADER_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: value, namespace: ['comet', 'allow_header']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:43 [everett] DEBUG: Looking up key: rest_v2_minimal_backend_version, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_REST_V2_MINIMAL_BACKEND_VERSION
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_REST_V2_MINIMAL_BACKEND_VERSION
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: rest_v2_minimal_backend_version, namespace: ['comet']
# 2024-02-07 21:19:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_REST_V2_MINIMAL_BACKEND_VERSION
# 2024-02-07 21:19:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:19:44 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): www.comet.com:443
# 2024-02-07 21:19:45 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "GET /clientlib/isAlive/ver HTTP/1.1" 200 81
# 2024-02-07 21:19:45 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "GET /api/rest/v2/workspaces HTTP/1.1" 200 33
# COMET INFO: Valid Comet API Key saved in /Users/admin/.comet.config (set COMET_CONFIG to change where it is saved).
# 2024-02-07 21:19:45 [everett] DEBUG: No INI file found: []
# 2024-02-07 21:19:45 [everett] DEBUG: No INI file found: ['./.comet.config']
# 2024-02-07 21:19:45 [everett] DEBUG: No INI file found: ['/content/drive/MyDrive/.comet.config']

# %%
# Resolve async issues by applying nest_asyncio
import nest_asyncio
nest_asyncio.apply()

# Import required modules from langchain
from langchain_openai import ChatOpenAI
from langchain_community.document_loaders import AsyncChromiumLoader
from langchain_community.document_transformers import BeautifulSoupTransformer
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import create_extraction_chain

# Define the URL
url = "https://www.imdb.com/list/ls566941243/"

# Initialize ChatOpenAI instance with OpenAI API key
llm = ChatOpenAI(openai_api_key=MY_OPENAI_KEY)

# Load HTML content using AsyncChromiumLoader
loader = AsyncChromiumLoader([url])
docs = loader.load()

# Save the HTML content to a text file for reference
with open("imdb_langchain_html.txt", "w", encoding="utf-8") as file:
    file.write(str(docs[0].page_content))
print("Page content has been saved to imdb_langchain_html.txt")

# Transform the loaded HTML using BeautifulSoupTransformer
bs_transformer = BeautifulSoupTransformer()
docs_transformed = bs_transformer.transform_documents(
    docs, tags_to_extract=["h3", "p"]
)

# Split the transformed documents using RecursiveCharacterTextSplitter
splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(chunk_size=1000, chunk_overlap=0)
splits = splitter.split_documents(docs_transformed)
# Out:
# 2024-02-07 21:19:52 [httpx] DEBUG: load_ssl_context verify=True cert=None trust_env=True http2=False
# 2024-02-07 21:19:52 [httpx] DEBUG: load_verify_locations cafile='/Users/admin/Desktop/medium-how-to-web-scraping/.venv/lib/python3.10/site-packages/certifi/cacert.pem'
# 2024-02-07 21:19:52 [httpx] DEBUG: load_ssl_context verify=True cert=None trust_env=True http2=False
# 2024-02-07 21:19:52 [httpx] DEBUG: load_verify_locations cafile='/Users/admin/Desktop/medium-how-to-web-scraping/.venv/lib/python3.10/site-packages/certifi/cacert.pem'
# 2024-02-07 21:19:52 [langchain_community.document_loaders.chromium] INFO: Starting scraping...
# 2024-02-07 21:20:06 [langchain_community.document_loaders.chromium] INFO: Content scraped
# Page content has been saved to imdb_langchain_html.txt

# %%
# Define a JSON schema for movie data validation
schema = {
    "properties": {
        "movie_title": {"type": "string"},
        "stars": {"type": "integer"},
        "genre": {"type": "array", "items": {"type": "string"}},
        "runtime": {"type": "string"},
        "rating": {"type": "string"},
    },
    "required": ["movie_title", "stars", "genre", "runtime", "rating"],
}

def extract_movie_data(content: str, schema: dict):
    """
    Extract movie data from content using a specified JSON schema.

    Parameters:
    - content (str): Text content containing movie data.
    - schema (dict): JSON schema for validating the movie data.

    Returns:
    - dict: Extracted movie data.
    """
    # Run the extraction chain with the provided schema and content
    start_time = time.time()
    extracted_content = create_extraction_chain(schema=schema, llm=llm).run(content)
    end_time = time.time()

    # Log metadata and output in the Comet project for tracking purposes
    comet_llm.log_prompt(
        prompt=str(content),
        metadata= {
            "schema": schema
        },
        output= extracted_content,
        duration= end_time - start_time,
    )

    return extracted_content

# %%
# Extract movie data using the defined schema and the first split page content
extracted_content = extract_movie_data(schema=schema, content=splits[0].page_content)

# Display the extracted movie data
extracted_content
# Out:
# 2024-02-07 21:20:19 [py.warnings] WARNING: /Users/admin/Desktop/medium-how-to-web-scraping/.venv/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
#
# 2024-02-07 21:20:19 [everett] DEBUG: Looking up key: api_key, namespace: ['comet']
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_API_KEY
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_API_KEY
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: api_key, namespace: ['comet']
# 2024-02-07 21:20:19 [everett] DEBUG: Returning raw: 'eP6Jhfasgx3pTkJ8B97eyKxkd', parsed: 'eP6Jhfasgx3pTkJ8B97eyKxkd'
# 2024-02-07 21:20:19 [everett] DEBUG: Looking up key: hide_api_key, namespace: ['comet', 'logging']
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_LOGGING_HIDE_API_KEY
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_LOGGING_HIDE_API_KEY
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: hide_api_key, namespace: ['comet', 'logging']
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_LOGGING_HIDE_API_KEY
# 2024-02-07 21:20:19 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:20:19 [everett] DEBUG: Looking up key: api_key, namespace: ['comet']
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_API_KEY
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_API_KEY
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: api_key, namespace: ['comet']
# 2024-02-07 21:20:19 [everett] DEBUG: Returning raw: 'eP6Jhfasgx3pTkJ8B97eyKxkd', parsed: 'eP6Jhfasgx3pTkJ8B97eyKxkd'
# 2024-02-07 21:20:19 [everett] DEBUG: Looking up key: hide_api_key, namespace: ['comet', 'logging']
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_LOGGING_HIDE_API_KEY
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_LOGGING_HIDE_API_KEY
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: hide_api_key, namespace: ['comet', 'logging']
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_LOGGING_HIDE_API_KEY
# 2024-02-07 21:20:19 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:20:19 [everett] DEBUG: Looking up key: workspace, namespace: ['comet']
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_WORKSPACE
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_WORKSPACE
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: workspace, namespace: ['comet']
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_WORKSPACE
# 2024-02-07 21:20:19 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:20:19 [everett] DEBUG: Looking up key: project_name, namespace: ['comet']
# 2024-02-07 21:20:19 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_PROJECT_NAME
# 2024-02-07 21:20:19 [everett] DEBUG: Returning raw: 'langchain-web-scraping', parsed: 'langchain-web-scraping'
# 2024-02-07 21:20:19 [openai._base_client] DEBUG: Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': "Extract and save the relevant entities mentioned in the following passage together with their properties.\n\nOnly extract the properties mentioned in the 'information_extraction' function.\n\nIf a property is not present and is not required in the function parameters, do not include it in the output.\n\nPassage:\nAction, Thriller, Spy, Detective, Drugs and Robbery  1.  Bullet Train (/title/tt12593682/?ref_=ttls_li_tt)  (2022)   18  |  127 min  |  Action, Comedy, Thriller  Five assassins aboard a swiftly-moving bullet train find out that their missions have something in common. Director: David Leitch (/name/nm0500610/?ref_=ttls_li_dr_0)  | Stars: Brad Pitt (/name/nm0000093/?ref_=ttls_li_st_0) , Joey King (/name/nm1428821/?ref_=ttls_li_st_1) , Aaron Taylor-Johnson (/name/nm1093951/?ref_=ttls_li_st_2) , Brian Tyree Henry (/name/nm3109964/?ref_=ttls_li_st_3)   Votes:  410,011  |  Gross:  $103.37M   2.  Emancipation (/title/tt12530246/?ref_=ttls_li_tt)  (2022)   R  |  132 min  |  Action, Thriller  A runaway slave forges through the swamps of Louisiana on a tortuous journey to escape plantation owners that nearly killed him. Director: Antoine Fuqua (/name/nm0298807/?ref_=ttls_li_dr_0)  | Stars: Will Smith (/name/nm0000226/?ref_=ttls_li_st_0) , Ben Foster (/name/nm0004936/?ref_=ttls_li_st_1) , Charmaine Bingwa (/name/nm6192439/?ref_=ttls_li_st_2) , Gilbert Owuor (/name/nm4114489/?ref_=ttls_li_st_3)   Votes:  26,399   3.  Violent Night (/title/tt12003946/?ref_=ttls_li_tt)  (2022)   R  |  112 min  |  Action, Comedy, Thriller  An elite team of mercenaries breaks into a family compound on Christmas Eve, taking everyone hostage. However, they aren't prepared for a surprise combatant: Santa Claus is on the grounds, and he's about to show why this Nick is no saint. Director: Tommy Wirkola (/name/nm2482088/?ref_=ttls_li_dr_0)  | Stars: David Harbour (/name/nm1092086/?ref_=ttls_li_st_0) , John Leguizamo (/name/nm0000491/?ref_=ttls_li_st_1) , Beverly D'Angelo (/name/nm0000350/?ref_=ttls_li_st_2) , Alex Hassell (/name/nm1307435/?ref_=ttls_li_st_3)   Votes:  97,135   4.  Top Gun: Maverick (/title/tt1745960/?ref_=ttls_li_tt)  (2022)   P13  |  130 min  |  Action, Drama  After thirty years, Maverick is still pushing the envelope as a top naval aviator, but must confront ghosts of his past when he leads TOP GUN's elite graduates on a mission that demands the ultimate sacrifice from those chosen to fly it. Director: Joseph Kosinski (/name/nm2676052/?ref_=ttls_li_dr_0)  | Stars: Tom Cruise (/name/nm0000129/?ref_=ttls_li_st_0) , Jennifer Connelly (/name/nm0000124/?ref_=ttls_li_st_1) , Miles Teller (/name/nm1886602/?ref_=ttls_li_st_2) , Val Kilmer (/name/nm0000174/?ref_=ttls_li_st_3)   Votes:  671,660  |  Gross:  $718.73M   5.  The Batman (/title/tt1877830/?ref_=ttls_li_tt)  (2022)   P13  |  176 min  |  Action, Crime, Drama  When a sadistic serial killer begins murdering key political figures in Gotham, Batman is forced to investigate the city's hidden corruption and question his family's involvement. Director: Matt Reeves (/name/nm0716257/?ref_=ttls_li_dr_0)\n"}], 'model': 'gpt-3.5-turbo', 'function_call': {'name': 'information_extraction'}, 'functions': [{'name': 'information_extraction', 'description': 'Extracts the relevant information from the passage.', 'parameters': {'type': 'object', 'properties': {'info': {'type': 'array', 'items': {'type': 'object', 'properties': {'movie_title': {'title': 'movie_title', 'type': 'string'}, 'stars': {'title': 'stars', 'type': 'integer'}, 'genre': {'title': 'genre', 'type': 'array', 'items': {'type': 'string'}}, 'runtime': {'title': 'runtime', 'type': 'string'}, 'rating': {'title': 'rating', 'type': 'string'}}, 'required': ['movie_title', 'stars', 'genre', 'runtime', 'rating']}}}, 'required': ['info']}}], 'n': 1, 'stream': False, 't ...
# 2024-02-07 21:20:19 [httpcore.connection] DEBUG: connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=None socket_options=None
# 2024-02-07 21:20:19 [httpcore.connection] DEBUG: connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x128b0b3a0>
# 2024-02-07 21:20:19 [httpcore.connection] DEBUG: start_tls.started ssl_context=<ssl.SSLContext object at 0x126fb8ac0> server_hostname='api.openai.com' timeout=None
# 2024-02-07 21:20:19 [httpcore.connection] DEBUG: start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x128b0b3d0>
# 2024-02-07 21:20:19 [httpcore.http11] DEBUG: send_request_headers.started request=<Request [b'POST']>
# 2024-02-07 21:20:19 [httpcore.http11] DEBUG: send_request_headers.complete
# 2024-02-07 21:20:19 [httpcore.http11] DEBUG: send_request_body.started request=<Request [b'POST']>
# 2024-02-07 21:20:19 [httpcore.http11] DEBUG: send_request_body.complete
# 2024-02-07 21:20:19 [httpcore.http11] DEBUG: receive_response_headers.started request=<Request [b'POST']>
# 2024-02-07 21:20:34 [httpcore.http11] DEBUG: receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 07 Feb 2024 13:20:34 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'Cache-Control', b'no-cache, must-revalidate'), (b'openai-model', b'gpt-3.5-turbo-0613'), (b'openai-organization', b'user-woitd5fzi1ohlhcywxxhrwyk'), (b'openai-processing-ms', b'13921'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'60000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'59212'), (b'x-ratelimit-reset-requests', b'8.64s'), (b'x-ratelimit-reset-tokens', b'788ms'), (b'x-request-id', b'0ef775d9172bacdec1e6d1dc299bd168'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=_aIvpvzcOb0GEZBC.6ONygRx36Ig.R3.8IMTfEBRxPI-1707312034-1-Acw1iN0FGpnqHsGggSZkv4tV7WPNMIbEK7FNc/sVUDDI9KputMkOPK0R3IM5+JFOitFPr0Kz/CyDGEZ55nNOOKg=; path=/; expires=Wed, 07-Feb-24 13:50:34 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Set-Cookie', b'_cfuvid=sfvHuflyKKLMZWd7j_kXzpCoBIErlPOOSgYUmeJmMK4-1707312034681-0-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'851bedfcacf413e1-KUL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2024-02-07 21:20:34 [httpx] INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-02-07 21:20:34 [httpcore.http11] DEBUG: receive_response_body.started request=<Request [b'POST']>
# 2024-02-07 21:20:34 [httpcore.http11] DEBUG: receive_response_body.complete
# 2024-02-07 21:20:34 [httpcore.http11] DEBUG: response_closed.started
# 2024-02-07 21:20:34 [httpcore.http11] DEBUG: response_closed.complete
# 2024-02-07 21:20:34 [openai._base_client] DEBUG: HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# 2024-02-07 21:20:34 [everett] DEBUG: Looking up key: api_key, namespace: ['comet']
# 2024-02-07 21:20:34 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_API_KEY
# 2024-02-07 21:20:34 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_API_KEY
# 2024-02-07 21:20:34 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: api_key, namespace: ['comet']
# 2024-02-07 21:20:34 [everett] DEBUG: Returning raw: 'eP6Jhfasgx3pTkJ8B97eyKxkd', parsed: 'eP6Jhfasgx3pTkJ8B97eyKxkd'
# 2024-02-07 21:20:34 [everett] DEBUG: Looking up key: hide_api_key, namespace: ['comet', 'logging']
# 2024-02-07 21:20:34 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_LOGGING_HIDE_API_KEY
# 2024-02-07 21:20:34 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_LOGGING_HIDE_API_KEY
# 2024-02-07 21:20:34 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: hide_api_key, namespace: ['comet', 'logging']
# 2024-02-07 21:20:34 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_LOGGING_HIDE_API_KEY
# 2024-02-07 21:20:34 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:20:34 [everett] DEBUG: Looking up key: url_override, namespace: ['comet']
# 2024-02-07 21:20:34 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_URL_OVERRIDE
# 2024-02-07 21:20:34 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_URL_OVERRIDE
# 2024-02-07 21:20:34 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: url_override, namespace: ['comet']
# 2024-02-07 21:20:34 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_URL_OVERRIDE
# 2024-02-07 21:20:34 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:20:34 [everett] DEBUG: Looking up key: check_tls_certificate, namespace: ['comet', 'internal']
# 2024-02-07 21:20:34 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# 2024-02-07 21:20:34 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# 2024-02-07 21:20:34 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: check_tls_certificate, namespace: ['comet', 'internal']
# 2024-02-07 21:20:34 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# 2024-02-07 21:20:34 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:20:34 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): www.comet.com:443
# 2024-02-07 21:20:35 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/create HTTP/1.1" 200 244
# 2024-02-07 21:20:35 [everett] DEBUG: Looking up key: url_override, namespace: ['comet']
# 2024-02-07 21:20:35 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_URL_OVERRIDE
# 2024-02-07 21:20:35 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_URL_OVERRIDE
# 2024-02-07 21:20:35 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: url_override, namespace: ['comet']
# 2024-02-07 21:20:35 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_URL_OVERRIDE
# 2024-02-07 21:20:35 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:20:36 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/upload-asset?experimentKey=719fecd3b407403db65e67d0421d325c&fileName=comet_llm_data.json&extension=json&type=llm_data HTTP/1.1" 200 78
# 2024-02-07 21:20:36 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/metric HTTP/1.1" 200 55
# 2024-02-07 21:20:37 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:37 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:37 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:38 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:38 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:39 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:39 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:40 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:40 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:41 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:41 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:42 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:42 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:43 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:43 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/log-other HTTP/1.1" 200 55
# Chain logged to https://www.comet.com/yennhi95zz/langchain-web-scraping
# 2024-02-07 21:20:43 [comet_llm.summary] INFO: Chain logged to https://www.comet.com/yennhi95zz/langchain-web-scraping
# 2024-02-07 21:20:43 [everett] DEBUG: Looking up key: api_key, namespace: ['comet']
# 2024-02-07 21:20:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_API_KEY
# 2024-02-07 21:20:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_API_KEY
# 2024-02-07 21:20:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: api_key, namespace: ['comet']
# 2024-02-07 21:20:43 [everett] DEBUG: Returning raw: 'eP6Jhfasgx3pTkJ8B97eyKxkd', parsed: 'eP6Jhfasgx3pTkJ8B97eyKxkd'
# 2024-02-07 21:20:43 [everett] DEBUG: Looking up key: hide_api_key, namespace: ['comet', 'logging']
# 2024-02-07 21:20:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_LOGGING_HIDE_API_KEY
# 2024-02-07 21:20:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_LOGGING_HIDE_API_KEY
# 2024-02-07 21:20:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: hide_api_key, namespace: ['comet', 'logging']
# 2024-02-07 21:20:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_LOGGING_HIDE_API_KEY
# 2024-02-07 21:20:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:20:43 [everett] DEBUG: Looking up key: workspace, namespace: ['comet']
# 2024-02-07 21:20:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_WORKSPACE
# 2024-02-07 21:20:43 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_WORKSPACE
# 2024-02-07 21:20:43 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: workspace, namespace: ['comet']
# 2024-02-07 21:20:43 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_WORKSPACE
# 2024-02-07 21:20:43 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:20:43 [everett] DEBUG: Looking up key: project_name, namespace: ['comet']
# 2024-02-07 21:20:43 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_PROJECT_NAME
# 2024-02-07 21:20:43 [everett] DEBUG: Returning raw: 'langchain-web-scraping', parsed: 'langchain-web-scraping'
# 2024-02-07 21:20:44 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/create HTTP/1.1" 200 249
# 2024-02-07 21:20:44 [everett] DEBUG: Looking up key: url_override, namespace: ['comet']
# 2024-02-07 21:20:44 [everett] DEBUG: Searching <ConfigOSEnv> for COMET_URL_OVERRIDE
# 2024-02-07 21:20:44 [everett] DEBUG: Searching <ConfigEnvFileEnv: '/Users/admin/Desktop/medium-how-to-web-scraping/.env'> for COMET_URL_OVERRIDE
# 2024-02-07 21:20:44 [everett] DEBUG: Searching <ConfigIniEnv: /Users/admin/.comet.config> for key: url_override, namespace: ['comet']
# 2024-02-07 21:20:44 [everett] DEBUG: Searching <ConfigDictEnv: {}> for COMET_URL_OVERRIDE
# 2024-02-07 21:20:44 [everett] DEBUG: Found nothing--returning NO_VALUE
# 2024-02-07 21:20:44 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/upload-asset?experimentKey=d1defa5806654ec787ccff5f11a8d762&fileName=comet_llm_data.json&extension=json&type=llm_data HTTP/1.1" 200 78
# 2024-02-07 21:20:45 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/metric HTTP/1.1" 200 55
# 2024-02-07 21:20:45 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:46 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:46 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:47 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:47 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:47 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# 2024-02-07 21:20:48 [urllib3.connectionpool] DEBUG: https://www.comet.com:443 "POST /api/rest/v2/write/experiment/parameter HTTP/1.1" 200 55
# [{'movie_title': 'Bullet Train',
#   'stars': 18,
#   'genre': ['Action', 'Comedy', 'Thriller'],
#   'runtime': '127 min',
#   'rating': None},
#  {'movie_title': 'Emancipation',
#   'stars': None,
#   'genre': ['Action', 'Thriller'],
#   'runtime': '132 min',
#   'rating': 'R'},
#  {'movie_title': 'Violent Night',
#   'stars': None,
#   'genre': ['Action', 'Comedy', 'Thriller'],
#   'runtime': '112 min',
#   'rating': 'R'},
#  {'movie_title': 'Top Gun: Maverick',
#   'stars': None,
#   'genre': ['Action', 'Drama'],
#   'runtime': '130 min',
#   'rating': 'P13'},
#  {'movie_title': 'The Batman',
#   'stars': None,
#   'genre': ['Action', 'Crime', 'Drama'],
#   'runtime': '176 min',
#   'rating': 'P13'}]
